# %% [markdown]
# <a href="https://colab.research.google.com/github/farhadkamangar/CSE5368/blob/master/mainm_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install -qq pkg-config libcairo2-dev
# !pip3 install jupyter-manim --quiet
# !sudo apt-get -qq update
# !sudo apt-get install -qq texlive-full
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 38.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Building wheel for jupyter-manim (setup.py) ... done
#   Building wheel for manimlib (setup.py) ... done
#   Building wheel for progressbar (setup.py) ... done
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 342.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package install-info.
# (Reading database ... 252821 files and directories currently installed.)
# Preparing to unpack .../install-info_6.8-4build1_amd64.deb ...
# Unpacking install-info (6.8-4build1) ...
# Setting up install-info (6.8-4build1) ...
# Selecting previously unselected package fonts-arphic-bkai00mp.
# (Reading database ... 252834 files and directories currently installed.)
# Preparing to unpack .../000-fonts-arphic-bkai00mp_2.10-21_all.deb ...
# Unpacking fonts-arphic-bkai00mp (2.10-21) ...
# Selecting previously unselected package fonts-arphic-bsmi00lp.
# Preparing to unpack .../001-fonts-arphic-bsmi00lp_2.10-18_all.deb ...
# Unpacking fonts-arphic-bsmi00lp (2.10-18) ...
# Selecting previously unselected package fonts-arphic-uming.
# Preparing to unpack .../002-fonts-arphic-uming_0.2.20080216.2-10ubuntu2_all.deb ...
# Unpacking fonts-arphic-uming (0.2.20080216.2-10ubuntu2) ...
# Selecting previously unselected package fonts-ipafont-gothic.
# Preparing to unpack .../003-fonts-ipafont-gothic_00303-21ubuntu1_all.deb ...
# Unpacking fonts-ipafont-gothic (00303-21ubuntu1) ...
# Selecting previously unselected package fonts-ipafont-mincho.
# Preparing to unpack .../004-fonts-ipafont-mincho_00303-21ubuntu1_all.deb ...
# Unpacking fonts-ipafont-mincho (00303-21ubuntu1) ...
# Selecting previously unselected package fonts-unfonts-core.
# Preparing to unpack .../005-fonts-unfonts-core_1%3a1.0.2-080608-16_all.deb ...
# Unpacking fonts-unfonts-core (1:1.0.2-080608-16) ...
# Selecting previously unselected package fonts-unfonts-extra.
# Preparing to unpack .../006-fonts-unfonts-extra_1%3a1.0.2-080608+dfsg-9_all.deb ...
# Unpacking fonts-unfonts-extra (1:1.0.2-080608+dfsg-9) ...
# Selecting previously unselected package libfftw3-double3:amd64.
# Preparing to unpack .../007-libfftw3-double3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-double3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package liblqr-1-0:amd64.
# Preparing to unpack .../008-liblqr-1-0_0.4.2-2.1_amd64.deb ...
# Unpacking liblqr-1-0:amd64 (0.4.2-2.1) ...
# Selecting previously unselected package imagemagick-6-common.
# Preparing to unpack .../009-imagemagick-6-common_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.3_all.deb ...
# Unpacking imagemagick-6-common (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Selecting previously unselected package libmagickcore-6.q16-6:amd64.
# Preparing to unpack .../010-libmagickcore-6.q16-6_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.3_amd64.deb ...
# Unpacking libmagickcore-6.q16-6:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Selecting previously unselected package libmagickwand-6.q16-6:amd64.
# Preparing to unpack .../011-libmagickwand-6.q16-6_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.3_amd64.deb ...
# Unpacking libmagickwand-6.q16-6:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Selecting previously unselected package libmotif-common.
# Preparing to unpack .../012-libmotif-common_2.3.8-3_all.deb ...
# Unpacking libmotif-common (2.3.8-3) ...
# Selecting previously unselected package libqt5core5a:amd64.
# Preparing to unpack .../013-libqt5core5a_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libevdev2:amd64.
# Preparing to unpack .../014-libevdev2_1.12.1+dfsg-1_amd64.deb ...
# Unpacking libevdev2:amd64 (1.12.1+dfsg-1) ...
# Selecting previously unselected package libmtdev1:amd64.
# Preparing to unpack .../015-libmtdev1_1.1.6-1build4_amd64.deb ...
# Unpacking libmtdev1:amd64 (1.1.6-1build4) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../016-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package libwacom-common.
# Preparing to unpack .../017-libwacom-common_2.2.0-1_all.deb ...
# Unpacking libwacom-common (2.2.0-1) ...
# Selecting previously unselected package libwacom9:amd64.
# Preparing to unpack .../018-libwacom9_2.2.0-1_amd64.deb ...
# Unpacking libwacom9:amd64 (2.2.0-1) ...
# Selecting previously unselected package libinput-bin.
# Preparing to unpack .../019-libinput-bin_1.20.0-1ubuntu0.3_amd64.deb ...
# Unpacking libinput-bin (1.20.0-1ubuntu0.3) ...
# Selecting previously unselected package libinput10:amd64.
# Preparing to unpack .../020-libinput10_1.20.0-1ubuntu0.3_amd64.deb ...
# Unpacking libinput10:amd64 (1.20.0-1ubuntu0.3) ...
# Selecting previously unselected package libmd4c0:amd64.
# Preparing to unpack .../021-libmd4c0_0.4.8-1_amd64.deb ...
# Unpacking libmd4c0:amd64 (0.4.8-1) ...
# Selecting previously unselected package libqt5dbus5:amd64.
# Preparing to unpack .../022-libqt5dbus5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5network5:amd64.
# Preparing to unpack .../023-libqt5network5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../024-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../025-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../026-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../027-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../028-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../029-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../030-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../031-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../032-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libqt5gui5:amd64.
# Preparing to unpack .../033-libqt5gui5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5widgets5:amd64.
# Preparing to unpack .../034-libqt5widgets5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5svg5:amd64.
# Preparing to unpack .../035-libqt5svg5_5.15.3-1_amd64.deb ...
# Unpacking libqt5svg5:amd64 (5.15.3-1) ...
# Selecting previously unselected package libxm4:amd64.
# Preparing to unpack .../036-libxm4_2.3.8-3_amd64.deb ...
# Unpacking libxm4:amd64 (2.3.8-3) ...
# Selecting previously unselected package sgml-base.
# Preparing to unpack .../037-sgml-base_1.30_all.deb ...
# Unpacking sgml-base (1.30) ...
# Selecting previously unselected package netbase.
# Preparing to unpack .../038-netbase_6.3_all.deb ...
# Unpacking netbase (6.3) ...
# Selecting previously unselected package info.
# Preparing to unpack .../039-info_6.8-4build1_amd64.deb ...
# Unpacking info (6.8-4build1) ...
# Selecting previously unselected package freeglut3:amd64.
# Preparing to unpack .../040-freeglut3_2.8.1-6_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-6) ...
# Selecting previously unselected package libgslcblas0:amd64.
# Preparing to unpack .../041-libgslcblas0_2.7.1+dfsg-3_amd64.deb ...
# Unpacking libgslcblas0:amd64 (2.7.1+dfsg-3) ...
# Selecting previously unselected package libgsl27:amd64.
# Preparing to unpack .../042-libgsl27_2.7.1+dfsg-3_amd64.deb ...
# Unpacking libgsl27:amd64 (2.7.1+dfsg-3) ...
# Selecting previously unselected package ghostscript.
# Preparing to unpack .../043-ghostscript_9.55.0~dfsg1-0ubuntu5.5_amd64.deb ...
# Unpacking ghostscript (9.55.0~dfsg1-0ubuntu5.5) ...
# Selecting previously unselected package imagemagick-6.q16.
# Preparing to unpack .../044-imagemagick-6.q16_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.3_amd64.deb ...
# Unpacking imagemagick-6.q16 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Selecting previously unselected package imagemagick.
# Preparing to unpack .../045-imagemagick_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.3_amd64.deb ...
# Unpacking imagemagick (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Selecting previously unselected package texlive-pstricks.
# Preparing to unpack .../046-texlive-pstricks_2021.20220204-1_all.deb ...
# Unpacking texlive-pstricks (2021.20220204-1) ...
# Selecting previously unselected package asymptote.
# Preparing to unpack .../047-asymptote_2.78+ds-2_amd64.deb ...
# Unpacking asymptote (2.78+ds-2) ...
# Selecting previously unselected package asymptote-doc.
# Preparing to unpack .../048-asymptote-doc_2.78+ds-2_all.deb ...
# Unpacking asymptote-doc (2.78+ds-2) ...
# Selecting previously unselected package libautovivification-perl.
# Preparing to unpack .../049-libautovivification-perl_0.18-1build4_amd64.deb ...
# Unpacking libautovivification-perl (0.18-1build4) ...
# Selecting previously unselected package libsub-name-perl.
# Preparing to unpack .../050-libsub-name-perl_0.26-1build3_amd64.deb ...
# Unpacking libsub-name-perl (0.26-1build3) ...
# Selecting previously unselected package libclass-accessor-perl.
# Preparing to unpack .../051-libclass-accessor-perl_0.51-1_all.deb ...
# Unpacking libclass-accessor-perl (0.51-1) ...
# Selecting previously unselected package libclone-perl.
# Preparing to unpack .../052-libclone-perl_0.45-1build3_amd64.deb ...
# Unpacking libclone-perl (0.45-1build3) ...
# Selecting previously unselected package libnumber-compare-perl.
# Preparing to unpack .../053-libnumber-compare-perl_0.03-2_all.deb ...
# Unpacking libnumber-compare-perl (0.03-2) ...
# Selecting previously unselected package libtext-glob-perl.
# Preparing to unpack .../054-libtext-glob-perl_0.11-2_all.deb ...
# Unpacking libtext-glob-perl (0.11-2) ...
# Selecting previously unselected package libfile-find-rule-perl.
# Preparing to unpack .../055-libfile-find-rule-perl_0.34-1_all.deb ...
# Unpacking libfile-find-rule-perl (0.34-1) ...
# Selecting previously unselected package libdata-compare-perl.
# Preparing to unpack .../056-libdata-compare-perl_1.27-1_all.deb ...
# Unpacking libdata-compare-perl (1.27-1) ...
# Selecting previously unselected package libdata-dump-perl.
# Preparing to unpack .../057-libdata-dump-perl_1.25-1_all.deb ...
# Unpacking libdata-dump-perl (1.25-1) ...
# Selecting previously unselected package libdata-uniqid-perl.
# Preparing to unpack .../058-libdata-uniqid-perl_0.12-1.1_all.deb ...
# Unpacking libdata-uniqid-perl (0.12-1.1) ...
# Selecting previously unselected package libdate-simple-perl.
# Preparing to unpack .../059-libdate-simple-perl_3.0300-3build2_amd64.deb ...
# Unpacking libdate-simple-perl (3.0300-3build2) ...
# Selecting previously unselected package libclass-inspector-perl.
# Preparing to unpack .../060-libclass-inspector-perl_1.36-1_all.deb ...
# Unpacking libclass-inspector-perl (1.36-1) ...
# Selecting previously unselected package libfile-sharedir-perl.
# Preparing to unpack .../061-libfile-sharedir-perl_1.118-1_all.deb ...
# Unpacking libfile-sharedir-perl (1.118-1) ...
# Selecting previously unselected package libb-hooks-op-check-perl.
# Preparing to unpack .../062-libb-hooks-op-check-perl_0.22-1build5_amd64.deb ...
# Unpacking libb-hooks-op-check-perl (0.22-1build5) ...
# Selecting previously unselected package libdynaloader-functions-perl.
# Preparing to unpack .../063-libdynaloader-functions-perl_0.003-1.1_all.deb ...
# Unpacking libdynaloader-functions-perl (0.003-1.1) ...
# Selecting previously unselected package libdevel-callchecker-perl.
# Preparing to unpack .../064-libdevel-callchecker-perl_0.008-1ubuntu4_amd64.deb ...
# Unpacking libdevel-callchecker-perl (0.008-1ubuntu4) ...
# Selecting previously unselected package libparams-classify-perl.
# Preparing to unpack .../065-libparams-classify-perl_0.015-1build5_amd64.deb ...
# Unpacking libparams-classify-perl (0.015-1build5) ...
# Selecting previously unselected package libmodule-runtime-perl.
# Preparing to unpack .../066-libmodule-runtime-perl_0.016-1_all.deb ...
# Unpacking libmodule-runtime-perl (0.016-1) ...
# Selecting previously unselected package libtry-tiny-perl.
# Preparing to unpack .../067-libtry-tiny-perl_0.31-1_all.deb ...
# Unpacking libtry-tiny-perl (0.31-1) ...
# Selecting previously unselected package libmodule-implementation-perl.
# Preparing to unpack .../068-libmodule-implementation-perl_0.09-1.1_all.deb ...
# Unpacking libmodule-implementation-perl (0.09-1.1) ...
# Selecting previously unselected package libsub-exporter-progressive-perl.
# Preparing to unpack .../069-libsub-exporter-progressive-perl_0.001013-1_all.deb ...
# Unpacking libsub-exporter-progressive-perl (0.001013-1) ...
# Selecting previously unselected package libvariable-magic-perl.
# Preparing to unpack .../070-libvariable-magic-perl_0.62-1build5_amd64.deb ...
# Unpacking libvariable-magic-perl (0.62-1build5) ...
# Selecting previously unselected package libb-hooks-endofscope-perl.
# Preparing to unpack .../071-libb-hooks-endofscope-perl_0.25-1_all.deb ...
# Unpacking libb-hooks-endofscope-perl (0.25-1) ...
# Selecting previously unselected package libscalar-list-utils-perl.
# Preparing to unpack .../072-libscalar-list-utils-perl_1%3a1.61-1_amd64.deb ...
# Unpacking libscalar-list-utils-perl (1:1.61-1) ...
# Selecting previously unselected package libpackage-stash-perl.
# Preparing to unpack .../073-libpackage-stash-perl_0.39-1_all.deb ...
# Unpacking libpackage-stash-perl (0.39-1) ...
# Selecting previously unselected package libsub-identify-perl.
# Preparing to unpack .../074-libsub-identify-perl_0.14-1build5_amd64.deb ...
# Unpacking libsub-identify-perl (0.14-1build5) ...
# Selecting previously unselected package libnamespace-clean-perl.
# Preparing to unpack .../075-libnamespace-clean-perl_0.27-1_all.deb ...
# Unpacking libnamespace-clean-perl (0.27-1) ...
# Selecting previously unselected package libnamespace-autoclean-perl.
# Preparing to unpack .../076-libnamespace-autoclean-perl_0.29-1_all.deb ...
# Unpacking libnamespace-autoclean-perl (0.29-1) ...
# Selecting previously unselected package libparams-util-perl.
# Preparing to unpack .../077-libparams-util-perl_1.102-1build3_amd64.deb ...
# Unpacking libparams-util-perl (1.102-1build3) ...
# Selecting previously unselected package libsub-install-perl.
# Preparing to unpack .../078-libsub-install-perl_0.928-1.1_all.deb ...
# Unpacking libsub-install-perl (0.928-1.1) ...
# Selecting previously unselected package libdata-optlist-perl.
# Preparing to unpack .../079-libdata-optlist-perl_0.112-1_all.deb ...
# Unpacking libdata-optlist-perl (0.112-1) ...
# Selecting previously unselected package libsub-exporter-perl.
# Preparing to unpack .../080-libsub-exporter-perl_0.988-1_all.deb ...
# Unpacking libsub-exporter-perl (0.988-1) ...
# Selecting previously unselected package libeval-closure-perl.
# Preparing to unpack .../081-libeval-closure-perl_0.14-1_all.deb ...
# Unpacking libeval-closure-perl (0.14-1) ...
# Selecting previously unselected package libclass-data-inheritable-perl.
# Preparing to unpack .../082-libclass-data-inheritable-perl_0.08-3_all.deb ...
# Unpacking libclass-data-inheritable-perl (0.08-3) ...
# Selecting previously unselected package libdevel-stacktrace-perl.
# Preparing to unpack .../083-libdevel-stacktrace-perl_2.0400-1_all.deb ...
# Unpacking libdevel-stacktrace-perl (2.0400-1) ...
# Selecting previously unselected package libexception-class-perl.
# Preparing to unpack .../084-libexception-class-perl_1.45-1_all.deb ...
# Unpacking libexception-class-perl (1.45-1) ...
# Selecting previously unselected package libparams-validationcompiler-perl.
# Preparing to unpack .../085-libparams-validationcompiler-perl_0.30-1_all.deb ...
# Unpacking libparams-validationcompiler-perl (0.30-1) ...
# Selecting previously unselected package libalgorithm-c3-perl.
# Preparing to unpack .../086-libalgorithm-c3-perl_0.11-1_all.deb ...
# Unpacking libalgorithm-c3-perl (0.11-1) ...
# Selecting previously unselected package libclass-c3-perl.
# Preparing to unpack .../087-libclass-c3-perl_0.35-1_all.deb ...
# Unpacking libclass-c3-perl (0.35-1) ...
# Selecting previously unselected package libmro-compat-perl.
# Preparing to unpack .../088-libmro-compat-perl_0.15-1_all.deb ...
# Unpacking libmro-compat-perl (0.15-1) ...
# Selecting previously unselected package libclass-method-modifiers-perl.
# Preparing to unpack .../089-libclass-method-modifiers-perl_2.13-1_all.deb ...
# Unpacking libclass-method-modifiers-perl (2.13-1) ...
# Selecting previously unselected package librole-tiny-perl.
# Preparing to unpack .../090-librole-tiny-perl_2.002004-1_all.deb ...
# Unpacking librole-tiny-perl (2.002004-1) ...
# Selecting previously unselected package libsub-quote-perl.
# Preparing to unpack .../091-libsub-quote-perl_2.006006-1_all.deb ...
# Unpacking libsub-quote-perl (2.006006-1) ...
# Selecting previously unselected package libxstring-perl.
# Preparing to unpack .../092-libxstring-perl_0.005-1build2_amd64.deb ...
# Unpacking libxstring-perl (0.005-1build2) ...
# Selecting previously unselected package libspecio-perl.
# Preparing to unpack .../093-libspecio-perl_0.47-1_all.deb ...
# Unpacking libspecio-perl (0.47-1) ...
# Selecting previously unselected package libdatetime-locale-perl.
# Preparing to unpack .../094-libdatetime-locale-perl_1%3a1.33-1_all.deb ...
# Unpacking libdatetime-locale-perl (1:1.33-1) ...
# Selecting previously unselected package libclass-singleton-perl.
# Preparing to unpack .../095-libclass-singleton-perl_1.6-1_all.deb ...
# Unpacking libclass-singleton-perl (1.6-1) ...
# Selecting previously unselected package libdatetime-timezone-perl.
# Preparing to unpack .../096-libdatetime-timezone-perl_1%3a2.51-1+2021e_all.deb ...
# Unpacking libdatetime-timezone-perl (1:2.51-1+2021e) ...
# Selecting previously unselected package libdatetime-perl:amd64.
# Preparing to unpack .../097-libdatetime-perl_2%3a1.55-1build1_amd64.deb ...
# Unpacking libdatetime-perl:amd64 (2:1.55-1build1) ...
# Selecting previously unselected package libdatetime-format-strptime-perl.
# Preparing to unpack .../098-libdatetime-format-strptime-perl_1.7900-1_all.deb ...
# Unpacking libdatetime-format-strptime-perl (1.7900-1) ...
# Selecting previously unselected package libparams-validate-perl:amd64.
# Preparing to unpack .../099-libparams-validate-perl_1.30-1build3_amd64.deb ...
# Unpacking libparams-validate-perl:amd64 (1.30-1build3) ...
# Selecting previously unselected package libdatetime-format-builder-perl.
# Preparing to unpack .../100-libdatetime-format-builder-perl_0.8300-1_all.deb ...
# Unpacking libdatetime-format-builder-perl (0.8300-1) ...
# Selecting previously unselected package libdatetime-calendar-julian-perl.
# Preparing to unpack .../101-libdatetime-calendar-julian-perl_0.107-1_all.deb ...
# Unpacking libdatetime-calendar-julian-perl (0.107-1) ...
# Selecting previously unselected package libencode-eucjpms-perl.
# Preparing to unpack .../102-libencode-eucjpms-perl_0.07-3build9_amd64.deb ...
# Unpacking libencode-eucjpms-perl (0.07-3build9) ...
# Selecting previously unselected package libencode-hanextra-perl.
# Preparing to unpack .../103-libencode-hanextra-perl_0.23-5build4_amd64.deb ...
# Unpacking libencode-hanextra-perl (0.23-5build4) ...
# Selecting previously unselected package libencode-jis2k-perl.
# Preparing to unpack .../104-libencode-jis2k-perl_0.03-1build7_amd64.deb ...
# Unpacking libencode-jis2k-perl (0.03-1build7) ...
# Selecting previously unselected package libfile-slurper-perl.
# Preparing to unpack .../105-libfile-slurper-perl_0.013-1_all.deb ...
# Unpacking libfile-slurper-perl (0.013-1) ...
# Selecting previously unselected package libipc-run3-perl.
# Preparing to unpack .../106-libipc-run3-perl_0.048-2_all.deb ...
# Unpacking libipc-run3-perl (0.048-2) ...
# Selecting previously unselected package perl-openssl-defaults:amd64.
# Preparing to unpack .../107-perl-openssl-defaults_5build2_amd64.deb ...
# Unpacking perl-openssl-defaults:amd64 (5build2) ...
# Selecting previously unselected package libnet-ssleay-perl:amd64.
# Preparing to unpack .../108-libnet-ssleay-perl_1.92-1build2_amd64.deb ...
# Unpacking libnet-ssleay-perl:amd64 (1.92-1build2) ...
# Selecting previously unselected package libio-socket-ssl-perl.
# Preparing to unpack .../109-libio-socket-ssl-perl_2.074-2_all.deb ...
# Unpacking libio-socket-ssl-perl (2.074-2) ...
# Selecting previously unselected package liburi-perl.
# Preparing to unpack .../110-liburi-perl_5.10-1_all.deb ...
# Unpacking liburi-perl (5.10-1) ...
# Selecting previously unselected package libnet-http-perl.
# Preparing to unpack .../111-libnet-http-perl_6.22-1_all.deb ...
# Unpacking libnet-http-perl (6.22-1) ...
# Selecting previously unselected package libencode-locale-perl.
# Preparing to unpack .../112-libencode-locale-perl_1.05-1.1_all.deb ...
# Unpacking libencode-locale-perl (1.05-1.1) ...
# Selecting previously unselected package libhttp-date-perl.
# Preparing to unpack .../113-libhttp-date-perl_6.05-1_all.deb ...
# Unpacking libhttp-date-perl (6.05-1) ...
# Selecting previously unselected package libfile-listing-perl.
# Preparing to unpack .../114-libfile-listing-perl_6.14-1_all.deb ...
# Unpacking libfile-listing-perl (6.14-1) ...
# Selecting previously unselected package libhtml-tagset-perl.
# Preparing to unpack .../115-libhtml-tagset-perl_3.20-4_all.deb ...
# Unpacking libhtml-tagset-perl (3.20-4) ...
# Selecting previously unselected package libhtml-parser-perl:amd64.
# Preparing to unpack .../116-libhtml-parser-perl_3.76-1build2_amd64.deb ...
# Unpacking libhtml-parser-perl:amd64 (3.76-1build2) ...
# Selecting previously unselected package libhtml-tree-perl.
# Preparing to unpack .../117-libhtml-tree-perl_5.07-2_all.deb ...
# Unpacking libhtml-tree-perl (5.07-2) ...
# Selecting previously unselected package libencode-perl:amd64.
# Preparing to unpack .../118-libencode-perl_3.16-1build1_amd64.deb ...
# Unpacking libencode-perl:amd64 (3.16-1build1) ...
# Selecting previously unselected package libio-html-perl.
# Preparing to unpack .../119-libio-html-perl_1.004-2_all.deb ...
# Unpacking libio-html-perl (1.004-2) ...
# Selecting previously unselected package liblwp-mediatypes-perl.
# Preparing to unpack .../120-liblwp-mediatypes-perl_6.04-1_all.deb ...
# Unpacking liblwp-mediatypes-perl (6.04-1) ...
# Selecting previously unselected package libhttp-message-perl.
# Preparing to unpack .../121-libhttp-message-perl_6.36-1_all.deb ...
# Unpacking libhttp-message-perl (6.36-1) ...
# Selecting previously unselected package libhttp-cookies-perl.
# Preparing to unpack .../122-libhttp-cookies-perl_6.10-1_all.deb ...
# Unpacking libhttp-cookies-perl (6.10-1) ...
# Selecting previously unselected package libhttp-negotiate-perl.
# Preparing to unpack .../123-libhttp-negotiate-perl_6.01-1_all.deb ...
# Unpacking libhttp-negotiate-perl (6.01-1) ...
# Selecting previously unselected package libwww-robotrules-perl.
# Preparing to unpack .../124-libwww-robotrules-perl_6.02-1_all.deb ...
# Unpacking libwww-robotrules-perl (6.02-1) ...
# Selecting previously unselected package libwww-perl.
# Preparing to unpack .../125-libwww-perl_6.61-1_all.deb ...
# Unpacking libwww-perl (6.61-1) ...
# Selecting previously unselected package liblwp-protocol-https-perl.
# Preparing to unpack .../126-liblwp-protocol-https-perl_6.10-1_all.deb ...
# Unpacking liblwp-protocol-https-perl (6.10-1) ...
# Selecting previously unselected package liblingua-translit-perl.
# Preparing to unpack .../127-liblingua-translit-perl_0.28-1_all.deb ...
# Unpacking liblingua-translit-perl (0.28-1) ...
# Selecting previously unselected package liblist-someutils-perl.
# Preparing to unpack .../128-liblist-someutils-perl_0.58-1_all.deb ...
# Unpacking liblist-someutils-perl (0.58-1) ...
# Selecting previously unselected package liblist-utilsby-perl.
# Preparing to unpack .../129-liblist-utilsby-perl_0.11-1_all.deb ...
# Unpacking liblist-utilsby-perl (0.11-1) ...
# Selecting previously unselected package liblist-allutils-perl.
# Preparing to unpack .../130-liblist-allutils-perl_0.19-1_all.deb ...
# Unpacking liblist-allutils-perl (0.19-1) ...
# Selecting previously unselected package libexporter-tiny-perl.
# Preparing to unpack .../131-libexporter-tiny-perl_1.002002-1_all.deb ...
# Unpacking libexporter-tiny-perl (1.002002-1) ...
# Selecting previously unselected package liblist-moreutils-xs-perl.
# Preparing to unpack .../132-liblist-moreutils-xs-perl_0.430-2build2_amd64.deb ...
# Unpacking liblist-moreutils-xs-perl (0.430-2build2) ...
# Selecting previously unselected package liblist-moreutils-perl.
# Preparing to unpack .../133-liblist-moreutils-perl_0.430-2_all.deb ...
# Unpacking liblist-moreutils-perl (0.430-2) ...
# Selecting previously unselected package liblog-log4perl-perl.
# Preparing to unpack .../134-liblog-log4perl-perl_1.54-1_all.deb ...
# Unpacking liblog-log4perl-perl (1.54-1) ...
# Selecting previously unselected package libparse-recdescent-perl.
# Preparing to unpack .../135-libparse-recdescent-perl_1.967015+dfsg-2_all.deb ...
# Unpacking libparse-recdescent-perl (1.967015+dfsg-2) ...
# Selecting previously unselected package libreadonly-perl.
# Preparing to unpack .../136-libreadonly-perl_2.050-3_all.deb ...
# Unpacking libreadonly-perl (2.050-3) ...
# Selecting previously unselected package libregexp-common-perl.
# Preparing to unpack .../137-libregexp-common-perl_2017060201-1_all.deb ...
# Unpacking libregexp-common-perl (2017060201-1) ...
# Selecting previously unselected package libsort-key-perl.
# Preparing to unpack .../138-libsort-key-perl_1.33-2build5_amd64.deb ...
# Unpacking libsort-key-perl (1.33-2build5) ...
# Selecting previously unselected package libbtparse2.
# Preparing to unpack .../139-libbtparse2_0.88-3build3_amd64.deb ...
# Unpacking libbtparse2 (0.88-3build3) ...
# Selecting previously unselected package libtext-bibtex-perl.
# Preparing to unpack .../140-libtext-bibtex-perl_0.88-3build3_amd64.deb ...
# Unpacking libtext-bibtex-perl (0.88-3build3) ...
# Selecting previously unselected package libtext-csv-perl.
# Preparing to unpack .../141-libtext-csv-perl_2.01-1_all.deb ...
# Unpacking libtext-csv-perl (2.01-1) ...
# Selecting previously unselected package libtext-csv-xs-perl:amd64.
# Preparing to unpack .../142-libtext-csv-xs-perl_1.47-1build1_amd64.deb ...
# Unpacking libtext-csv-xs-perl:amd64 (1.47-1build1) ...
# Selecting previously unselected package libtext-roman-perl.
# Preparing to unpack .../143-libtext-roman-perl_3.5-2.1_all.deb ...
# Unpacking libtext-roman-perl (3.5-2.1) ...
# Selecting previously unselected package libxml-namespacesupport-perl.
# Preparing to unpack .../144-libxml-namespacesupport-perl_1.12-1.1_all.deb ...
# Unpacking libxml-namespacesupport-perl (1.12-1.1) ...
# Selecting previously unselected package libxml-sax-base-perl.
# Preparing to unpack .../145-libxml-sax-base-perl_1.09-1.1_all.deb ...
# Unpacking libxml-sax-base-perl (1.09-1.1) ...
# Selecting previously unselected package libxml-sax-perl.
# Preparing to unpack .../146-libxml-sax-perl_1.02+dfsg-3_all.deb ...
# Unpacking libxml-sax-perl (1.02+dfsg-3) ...
# Selecting previously unselected package libxml-libxml-perl.
# Preparing to unpack .../147-libxml-libxml-perl_2.0207+dfsg+really+2.0134-1_amd64.deb ...
# Unpacking libxml-libxml-perl (2.0207+dfsg+really+2.0134-1) ...
# Selecting previously unselected package libxml-libxml-simple-perl.
# Preparing to unpack .../148-libxml-libxml-simple-perl_1.01-1_all.deb ...
# Unpacking libxml-libxml-simple-perl (1.01-1) ...
# Selecting previously unselected package libxml-libxslt-perl.
# Preparing to unpack .../149-libxml-libxslt-perl_1.99-1build2_amd64.deb ...
# Unpacking libxml-libxslt-perl (1.99-1build2) ...
# Selecting previously unselected package libxml-writer-perl.
# Preparing to unpack .../150-libxml-writer-perl_0.900-1_all.deb ...
# Unpacking libxml-writer-perl (0.900-1) ...
# Selecting previously unselected package libbusiness-isbn-data-perl.
# Preparing to unpack .../151-libbusiness-isbn-data-perl_20210112.006-1_all.deb ...
# Unpacking libbusiness-isbn-data-perl (20210112.006-1) ...
# Selecting previously unselected package libbusiness-isbn-perl.
# Preparing to unpack .../152-libbusiness-isbn-perl_3.006-1_all.deb ...
# Unpacking libbusiness-isbn-perl (3.006-1) ...
# Selecting previously unselected package libtie-cycle-perl.
# Preparing to unpack .../153-libtie-cycle-perl_1.226-1_all.deb ...
# Unpacking libtie-cycle-perl (1.226-1) ...
# Selecting previously unselected package libbusiness-ismn-perl.
# Preparing to unpack .../154-libbusiness-ismn-perl_1.202-1_all.deb ...
# Unpacking libbusiness-ismn-perl (1.202-1) ...
# Selecting previously unselected package libbusiness-issn-perl.
# Preparing to unpack .../155-libbusiness-issn-perl_1.005-1_all.deb ...
# Unpacking libbusiness-issn-perl (1.005-1) ...
# Selecting previously unselected package libsombok3:amd64.
# Preparing to unpack .../156-libsombok3_2.4.0-2_amd64.deb ...
# Unpacking libsombok3:amd64 (2.4.0-2) ...
# Selecting previously unselected package libmime-charset-perl.
# Preparing to unpack .../157-libmime-charset-perl_1.012.2-1_all.deb ...
# Unpacking libmime-charset-perl (1.012.2-1) ...
# Selecting previously unselected package libunicode-linebreak-perl.
# Preparing to unpack .../158-libunicode-linebreak-perl_0.0.20190101-1build3_amd64.deb ...
# Unpacking libunicode-linebreak-perl (0.0.20190101-1build3) ...
# Selecting previously unselected package biber.
# Preparing to unpack .../159-biber_2.17-2_all.deb ...
# Unpacking biber (2.17-2) ...
# Selecting previously unselected package chktex.
# Preparing to unpack .../160-chktex_1.7.6-4_amd64.deb ...
# Unpacking chktex (1.7.6-4) ...
# Selecting previously unselected package cm-super-minimal.
# Preparing to unpack .../161-cm-super-minimal_0.3.4-17_all.deb ...
# Unpacking cm-super-minimal (0.3.4-17) ...
# Selecting previously unselected package pfb2t1c2pfb.
# Preparing to unpack .../162-pfb2t1c2pfb_0.3-11_amd64.deb ...
# Unpacking pfb2t1c2pfb (0.3-11) ...
# Selecting previously unselected package cm-super.
# Preparing to unpack .../163-cm-super_0.3.4-17_all.deb ...
# Unpacking cm-super (0.3.4-17) ...
# Selecting previously unselected package texlive-metapost.
# Preparing to unpack .../164-texlive-metapost_2021.20220204-1_all.deb ...
# Unpacking texlive-metapost (2021.20220204-1) ...
# Selecting previously unselected package context.
# Preparing to unpack .../165-context_2021.03.05.20220211-1_all.deb ...
# Unpacking context (2021.03.05.20220211-1) ...
# Selecting previously unselected package context-modules.
# Preparing to unpack .../166-context-modules_20210301-1_all.deb ...
# Unpacking context-modules (20210301-1) ...
# Selecting previously unselected package cups-common.
# Preparing to unpack .../167-cups-common_2.4.1op1-1ubuntu4.7_all.deb ...
# Unpacking cups-common (2.4.1op1-1ubuntu4.7) ...
# Selecting previously unselected package cups-client.
# Preparing to unpack .../168-cups-client_2.4.1op1-1ubuntu4.7_amd64.deb ...
# Unpacking cups-client (2.4.1op1-1ubuntu4.7) ...
# Selecting previously unselected package dvidvi.
# Preparing to unpack .../169-dvidvi_1.0-8.2_amd64.deb ...
# Unpacking dvidvi (1.0-8.2) ...
# Selecting previously unselected package dvipng.
# Preparing to unpack .../170-dvipng_1.15-1.1_amd64.deb ...
# Unpacking dvipng (1.15-1.1) ...
# Selecting previously unselected package texlive-font-utils.
# Preparing to unpack .../171-texlive-font-utils_2021.20220204-1_all.deb ...
# Unpacking texlive-font-utils (2021.20220204-1) ...
# Selecting previously unselected package texlive-luatex.
# Preparing to unpack .../172-texlive-luatex_2021.20220204-1_all.deb ...
# Unpacking texlive-luatex (2021.20220204-1) ...
# Selecting previously unselected package texlive-extra-utils.
# Preparing to unpack .../173-texlive-extra-utils_2021.20220204-1_all.deb ...
# Unpacking texlive-extra-utils (2021.20220204-1) ...
# Selecting previously unselected package feynmf.
# Preparing to unpack .../174-feynmf_1.08-13_all.deb ...
# Unpacking feynmf (1.08-13) ...
# Selecting previously unselected package fonts-arphic-gbsn00lp.
# Preparing to unpack .../175-fonts-arphic-gbsn00lp_2.11-16_all.deb ...
# Unpacking fonts-arphic-gbsn00lp (2.11-16) ...
# Selecting previously unselected package fonts-arphic-gkai00mp.
# Preparing to unpack .../176-fonts-arphic-gkai00mp_2.11-16_all.deb ...
# Unpacking fonts-arphic-gkai00mp (2.11-16) ...
# Selecting previously unselected package fonts-baekmuk.
# Preparing to unpack .../177-fonts-baekmuk_2.2-13_all.deb ...
# Unpacking fonts-baekmuk (2.2-13) ...
# Selecting previously unselected package fonts-gfs-bodoni-classic.
# Preparing to unpack .../178-fonts-gfs-bodoni-classic_1.1-6_all.deb ...
# Unpacking fonts-gfs-bodoni-classic (1.1-6) ...
# Selecting previously unselected package fonts-gfs-didot-classic.
# Preparing to unpack .../179-fonts-gfs-didot-classic_1.1-6_all.deb ...
# Unpacking fonts-gfs-didot-classic (1.1-6) ...
# Selecting previously unselected package fonts-gfs-gazis.
# Preparing to unpack .../180-fonts-gfs-gazis_1.1-6_all.deb ...
# Unpacking fonts-gfs-gazis (1.1-6) ...
# Selecting previously unselected package fonts-gfs-theokritos.
# Preparing to unpack .../181-fonts-gfs-theokritos_1.1-6_all.deb ...
# Unpacking fonts-gfs-theokritos (1.1-6) ...
# Selecting previously unselected package fonts-hosny-amiri.
# Preparing to unpack .../182-fonts-hosny-amiri_0.113-1_all.deb ...
# Unpacking fonts-hosny-amiri (0.113-1) ...
# Selecting previously unselected package fonts-ipaexfont-gothic.
# Preparing to unpack .../183-fonts-ipaexfont-gothic_00401-3ubuntu1_all.deb ...
# Unpacking fonts-ipaexfont-gothic (00401-3ubuntu1) ...
# Selecting previously unselected package fonts-ipaexfont-mincho.
# Preparing to unpack .../184-fonts-ipaexfont-mincho_00401-3ubuntu1_all.deb ...
# Unpacking fonts-ipaexfont-mincho (00401-3ubuntu1) ...
# Selecting previously unselected package fonts-sil-padauk.
# Preparing to unpack .../185-fonts-sil-padauk_5.000-3_all.deb ...
# Unpacking fonts-sil-padauk (5.000-3) ...
# Selecting previously unselected package fonts-tlwg-garuda-otf.
# Preparing to unpack .../186-fonts-tlwg-garuda-otf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-garuda-otf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-garuda.
# Preparing to unpack .../187-fonts-tlwg-garuda_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-garuda (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-kinnari-otf.
# Preparing to unpack .../188-fonts-tlwg-kinnari-otf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-kinnari-otf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-kinnari.
# Preparing to unpack .../189-fonts-tlwg-kinnari_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-kinnari (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-laksaman-otf.
# Preparing to unpack .../190-fonts-tlwg-laksaman-otf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-laksaman-otf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-laksaman.
# Preparing to unpack .../191-fonts-tlwg-laksaman_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-laksaman (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-loma-otf.
# Preparing to unpack .../192-fonts-tlwg-loma-otf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-loma-otf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-loma.
# Preparing to unpack .../193-fonts-tlwg-loma_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-loma (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-mono-otf.
# Preparing to unpack .../194-fonts-tlwg-mono-otf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-mono-otf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-mono.
# Preparing to unpack .../195-fonts-tlwg-mono_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-mono (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-norasi-otf.
# Preparing to unpack .../196-fonts-tlwg-norasi-otf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-norasi-otf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-norasi.
# Preparing to unpack .../197-fonts-tlwg-norasi_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-norasi (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-purisa-otf.
# Preparing to unpack .../198-fonts-tlwg-purisa-otf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-purisa-otf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-purisa.
# Preparing to unpack .../199-fonts-tlwg-purisa_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-purisa (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-sawasdee-otf.
# Preparing to unpack .../200-fonts-tlwg-sawasdee-otf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-sawasdee-otf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-sawasdee.
# Preparing to unpack .../201-fonts-tlwg-sawasdee_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-sawasdee (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-typewriter-otf.
# Preparing to unpack .../202-fonts-tlwg-typewriter-otf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-typewriter-otf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-typewriter.
# Preparing to unpack .../203-fonts-tlwg-typewriter_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-typewriter (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-typist-otf.
# Preparing to unpack .../204-fonts-tlwg-typist-otf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-typist-otf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-typist.
# Preparing to unpack .../205-fonts-tlwg-typist_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-typist (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-typo-otf.
# Preparing to unpack .../206-fonts-tlwg-typo-otf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-typo-otf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-typo.
# Preparing to unpack .../207-fonts-tlwg-typo_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-typo (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-umpush-otf.
# Preparing to unpack .../208-fonts-tlwg-umpush-otf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-umpush-otf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-umpush.
# Preparing to unpack .../209-fonts-tlwg-umpush_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-umpush (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-waree-otf.
# Preparing to unpack .../210-fonts-tlwg-waree-otf_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-waree-otf (1:0.7.3-1) ...
# Selecting previously unselected package fonts-tlwg-waree.
# Preparing to unpack .../211-fonts-tlwg-waree_1%3a0.7.3-1_all.deb ...
# Unpacking fonts-tlwg-waree (1:0.7.3-1) ...
# Selecting previously unselected package gsfonts.
# Preparing to unpack .../212-gsfonts_1%3a8.11+urwcyr1.0.7~pre44-4.5_all.deb ...
# Unpacking gsfonts (1:8.11+urwcyr1.0.7~pre44-4.5) ...
# Selecting previously unselected package gsfonts-x11.
# Preparing to unpack .../213-gsfonts-x11_0.28_all.deb ...
# Unpacking gsfonts-x11 (0.28) ...
# Selecting previously unselected package lacheck.
# Preparing to unpack .../214-lacheck_1.26-17_amd64.deb ...
# Unpacking lacheck (1.26-17) ...
# Selecting previously unselected package latex-cjk-common.
# Preparing to unpack .../215-latex-cjk-common_4.8.4+git20170127-4_amd64.deb ...
# Unpacking latex-cjk-common (4.8.4+git20170127-4) ...
# Selecting previously unselected package latex-cjk-chinese.
# Preparing to unpack .../216-latex-cjk-chinese_4.8.4+git20170127-4_amd64.deb ...
# Unpacking latex-cjk-chinese (4.8.4+git20170127-4) ...
# Selecting previously unselected package latex-cjk-japanese.
# Preparing to unpack .../217-latex-cjk-japanese_4.8.4+git20170127-4_amd64.deb ...
# Unpacking latex-cjk-japanese (4.8.4+git20170127-4) ...
# Selecting previously unselected package latex-cjk-korean.
# Preparing to unpack .../218-latex-cjk-korean_4.8.4+git20170127-4_all.deb ...
# Unpacking latex-cjk-korean (4.8.4+git20170127-4) ...
# Selecting previously unselected package texlive-lang-other.
# Preparing to unpack .../219-texlive-lang-other_2021.20220204-1_all.deb ...
# Unpacking texlive-lang-other (2021.20220204-1) ...
# Selecting previously unselected package latex-cjk-thai.
# Preparing to unpack .../220-latex-cjk-thai_4.8.4+git20170127-4_all.deb ...
# Unpacking latex-cjk-thai (4.8.4+git20170127-4) ...
# Selecting previously unselected package latex-cjk-chinese-arphic-bsmi00lp.
# Preparing to unpack .../221-latex-cjk-chinese-arphic-bsmi00lp_1.23+nmu1_all.deb ...
# Unpacking latex-cjk-chinese-arphic-bsmi00lp (1.23+nmu1) ...
# Selecting previously unselected package latex-cjk-chinese-arphic-bkai00mp.
# Preparing to unpack .../222-latex-cjk-chinese-arphic-bkai00mp_1.23+nmu1_all.deb ...
# Unpacking latex-cjk-chinese-arphic-bkai00mp (1.23+nmu1) ...
# Selecting previously unselected package latex-cjk-chinese-arphic-gbsn00lp.
# Preparing to unpack .../223-latex-cjk-chinese-arphic-gbsn00lp_1.23+nmu1_all.deb ...
# Unpacking latex-cjk-chinese-arphic-gbsn00lp (1.23+nmu1) ...
# Selecting previously unselected package latex-cjk-chinese-arphic-gkai00mp.
# Preparing to unpack .../224-latex-cjk-chinese-arphic-gkai00mp_1.23+nmu1_all.deb ...
# Unpacking latex-cjk-chinese-arphic-gkai00mp (1.23+nmu1) ...
# Selecting previously unselected package latex-cjk-japanese-wadalab.
# Preparing to unpack .../225-latex-cjk-japanese-wadalab_0.20050817-17.1_all.deb ...
# Unpacking latex-cjk-japanese-wadalab (0.20050817-17.1) ...
# Selecting previously unselected package latex-cjk-all.
# Preparing to unpack .../226-latex-cjk-all_4.8.4+git20170127-4_all.deb ...
# Unpacking latex-cjk-all (4.8.4+git20170127-4) ...
# Selecting previously unselected package latexdiff.
# Preparing to unpack .../227-latexdiff_1.3.1-1_all.deb ...
# Unpacking latexdiff (1.3.1-1) ...
# Selecting previously unselected package latexmk.
# Preparing to unpack .../228-latexmk_1%3a4.76-1_all.deb ...
# Unpacking latexmk (1:4.76-1) ...
# Selecting previously unselected package lcdf-typetools.
# Preparing to unpack .../229-lcdf-typetools_2.108-2_amd64.deb ...
# Unpacking lcdf-typetools (2.108-2) ...
# Selecting previously unselected package libclass-c3-xs-perl.
# Preparing to unpack .../230-libclass-c3-xs-perl_0.15-1build2_amd64.deb ...
# Unpacking libclass-c3-xs-perl (0.15-1build2) ...
# Selecting previously unselected package libclass-xsaccessor-perl.
# Preparing to unpack .../231-libclass-xsaccessor-perl_1.19-3build9_amd64.deb ...
# Unpacking libclass-xsaccessor-perl (1.19-3build9) ...
# Selecting previously unselected package libcommon-sense-perl:amd64.
# Preparing to unpack .../232-libcommon-sense-perl_3.75-2build1_amd64.deb ...
# Unpacking libcommon-sense-perl:amd64 (3.75-2build1) ...
# Selecting previously unselected package libpadwalker-perl.
# Preparing to unpack .../233-libpadwalker-perl_2.5-1build2_amd64.deb ...
# Unpacking libpadwalker-perl (2.5-1build2) ...
# Selecting previously unselected package libdevel-caller-perl.
# Preparing to unpack .../234-libdevel-caller-perl_2.06-2build4_amd64.deb ...
# Unpacking libdevel-caller-perl (2.06-2build4) ...
# Selecting previously unselected package libdevel-globaldestruction-perl.
# Preparing to unpack .../235-libdevel-globaldestruction-perl_0.14-1.1_all.deb ...
# Unpacking libdevel-globaldestruction-perl (0.14-1.1) ...
# Selecting previously unselected package libdevel-lexalias-perl.
# Preparing to unpack .../236-libdevel-lexalias-perl_0.05-2build4_amd64.deb ...
# Unpacking libdevel-lexalias-perl (0.05-2build4) ...
# Selecting previously unselected package libdist-checkconflicts-perl.
# Preparing to unpack .../237-libdist-checkconflicts-perl_0.11-1.1_all.deb ...
# Unpacking libdist-checkconflicts-perl (0.11-1.1) ...
# Selecting previously unselected package libdjvulibre-text.
# Preparing to unpack .../238-libdjvulibre-text_3.5.28-2build2_all.deb ...
# Unpacking libdjvulibre-text (3.5.28-2build2) ...
# Selecting previously unselected package libdjvulibre21:amd64.
# Preparing to unpack .../239-libdjvulibre21_3.5.28-2build2_amd64.deb ...
# Unpacking libdjvulibre21:amd64 (3.5.28-2build2) ...
# Selecting previously unselected package libemail-date-format-perl.
# Preparing to unpack .../240-libemail-date-format-perl_1.005-1.1_all.deb ...
# Unpacking libemail-date-format-perl (1.005-1.1) ...
# Selecting previously unselected package libemf1:amd64.
# Preparing to unpack .../241-libemf1_1.0.13-3_amd64.deb ...
# Unpacking libemf1:amd64 (1.0.13-3) ...
# Selecting previously unselected package libfile-which-perl.
# Preparing to unpack .../242-libfile-which-perl_1.23-1_all.deb ...
# Unpacking libfile-which-perl (1.23-1) ...
# Selecting previously unselected package libfile-homedir-perl.
# Preparing to unpack .../243-libfile-homedir-perl_1.006-1_all.deb ...
# Unpacking libfile-homedir-perl (1.006-1) ...
# Selecting previously unselected package libfont-afm-perl.
# Preparing to unpack .../244-libfont-afm-perl_1.20-3_all.deb ...
# Unpacking libfont-afm-perl (1.20-3) ...
# Selecting previously unselected package libhtml-form-perl.
# Preparing to unpack .../245-libhtml-form-perl_6.07-1_all.deb ...
# Unpacking libhtml-form-perl (6.07-1) ...
# Selecting previously unselected package libhtml-format-perl.
# Preparing to unpack .../246-libhtml-format-perl_2.12-1.1_all.deb ...
# Unpacking libhtml-format-perl (2.12-1.1) ...
# Selecting previously unselected package libhttp-daemon-perl.
# Preparing to unpack .../247-libhttp-daemon-perl_6.13-1ubuntu0.1_all.deb ...
# Unpacking libhttp-daemon-perl (6.13-1ubuntu0.1) ...
# Selecting previously unselected package libjson-perl.
# Preparing to unpack .../248-libjson-perl_4.04000-1_all.deb ...
# Unpacking libjson-perl (4.04000-1) ...
# Selecting previously unselected package libstring-crc32-perl:amd64.
# Preparing to unpack .../249-libstring-crc32-perl_2.100-1build1_amd64.deb ...
# Unpacking libstring-crc32-perl:amd64 (2.100-1build1) ...
# Selecting previously unselected package libipc-shareable-perl.
# Preparing to unpack .../250-libipc-shareable-perl_1.06-2_all.deb ...
# Unpacking libipc-shareable-perl (1.06-2) ...
# Selecting previously unselected package libtypes-serialiser-perl.
# Preparing to unpack .../251-libtypes-serialiser-perl_1.01-1_all.deb ...
# Unpacking libtypes-serialiser-perl (1.01-1) ...
# Selecting previously unselected package libjson-xs-perl.
# Preparing to unpack .../252-libjson-xs-perl_4.030-1build3_amd64.deb ...
# Unpacking libjson-xs-perl (4.030-1build3) ...
# Selecting previously unselected package libjxr0:amd64.
# Preparing to unpack .../253-libjxr0_1.2~git20170615.f752187-5_amd64.deb ...
# Unpacking libjxr0:amd64 (1.2~git20170615.f752187-5) ...
# Selecting previously unselected package libjxr-tools.
# Preparing to unpack .../254-libjxr-tools_1.2~git20170615.f752187-5_amd64.deb ...
# Unpacking libjxr-tools (1.2~git20170615.f752187-5) ...
# Selecting previously unselected package liblist-someutils-xs-perl.
# Preparing to unpack .../255-liblist-someutils-xs-perl_0.58-2build3_amd64.deb ...
# Unpacking liblist-someutils-xs-perl (0.58-2build3) ...
# Selecting previously unselected package liblog-dispatch-perl.
# Preparing to unpack .../256-liblog-dispatch-perl_2.70-1_all.deb ...
# Unpacking liblog-dispatch-perl (2.70-1) ...
# Selecting previously unselected package libmagick++-6.q16-8:amd64.
# Preparing to unpack .../257-libmagick++-6.q16-8_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.3_amd64.deb ...
# Unpacking libmagick++-6.q16-8:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Selecting previously unselected package libwmflite-0.2-7:amd64.
# Preparing to unpack .../258-libwmflite-0.2-7_0.2.12-5ubuntu1_amd64.deb ...
# ...
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up libencode-perl:amd64 (3.16-1build1) ...
# Setting up texlive-lang-italian (2021.20220204-1) ...
# Setting up libvariable-magic-perl (0.62-1build5) ...
# Setting up libio-html-perl (1.004-2) ...
# Setting up libb-hooks-op-check-perl (0.22-1build5) ...
# Setting up texlive-fonts-extra-doc (2021.20220204-1) ...
# Setting up liblist-moreutils-xs-perl (0.430-2build2) ...
# Setting up fonts-gfs-bodoni-classic (1.1-6) ...
# Setting up netpbm (2:10.0-15.4) ...
# Setting up libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up liblingua-translit-perl (0.28-1) ...
# Setting up latexdiff (1.3.1-1) ...
# Setting up libfftw3-double3:amd64 (3.3.8-2ubuntu8) ...
# Setting up fonts-tlwg-norasi (1:0.7.3-1) ...
# Setting up libparams-util-perl (1.102-1build3) ...
# Setting up fonts-tlwg-waree-otf (1:0.7.3-1) ...
# Setting up dvidvi (1.0-8.2) ...
# Setting up libmtdev1:amd64 (1.1.6-1build4) ...
# Setting up libsub-exporter-progressive-perl (0.001013-1) ...
# Setting up fonts-tlwg-sawasdee-otf (1:0.7.3-1) ...
# Setting up texlive-latex-recommended-doc (2021.20220204-1) ...
# Setting up texlive-lang-cyrillic (2021.20220204-1) ...
# Setting up libsub-name-perl (0.26-1build3) ...
# Setting up fonts-tlwg-typist-otf (1:0.7.3-1) ...
# Setting up libbusiness-ismn-perl (1.202-1) ...
# Setting up libtypes-serialiser-perl (1.01-1) ...
# Setting up latex-cjk-chinese-arphic-bsmi00lp (1.23+nmu1) ...
# Setting up texlive-lang-polish (2021.20220204-1) ...
# Setting up libparse-recdescent-perl (1.967015+dfsg-2) ...
# Setting up libostyle1c2 (1.4devel1-22) ...
# Setting up liblqr-1-0:amd64 (0.4.2-2.1) ...
# Setting up fonts-ipafont-mincho (00303-21ubuntu1) ...
# Setting up fonts-ipafont-gothic (00303-21ubuntu1) ...
# Setting up libmime-charset-perl (1.012.2-1) ...
# Setting up libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up texlive-humanities-doc (2021.20220204-1) ...
# Setting up libbusiness-isbn-data-perl (20210112.006-1) ...
# Setting up libjson-perl (4.04000-1) ...
# Setting up fonts-tlwg-garuda (1:0.7.3-1) ...
# Setting up librole-tiny-perl (2.002004-1) ...
# Setting up libipc-run3-perl (0.048-2) ...
# Setting up libmd4c0:amd64 (0.4.8-1) ...
# Setting up libfile-sharedir-perl (1.118-1) ...
# Setting up texlive-xetex (2021.20220204-1) ...
# Setting up libdevel-globaldestruction-perl (0.14-1.1) ...
# Setting up netbase (6.3) ...
# Setting up fonts-gfs-theokritos (1.1-6) ...
# Setting up sgml-base (1.30) ...
# Setting up libsub-quote-perl (2.006006-1) ...
# Setting up libdevel-stacktrace-perl (2.0400-1) ...
# Setting up fonts-baekmuk (2.2-13) ...
# Setting up libclass-xsaccessor-perl (1.19-3build9) ...
# Setting up fonts-tlwg-loma (1:0.7.3-1) ...
# Setting up libencode-hanextra-perl (0.23-5build4) ...
# Setting up texlive-pictures-doc (2021.20220204-1) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.2) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libdjvulibre-text (3.5.28-2build2) ...
# Setting up texlive-latex-base-doc (2021.20220204-1) ...
# Setting up libbusiness-issn-perl (1.005-1) ...
# Setting up latex-cjk-common (4.8.4+git20170127-4) ...
# Setting up texlive-lang-cjk (2021.20220204-1) ...
# Setting up prerex (6.8.0-1) ...
# Setting up libexporter-tiny-perl (1.002002-1) ...
# Setting up libclass-accessor-perl (0.51-1) ...
# Setting up texlive-lang-japanese (2021.20220204-1) ...
# Setting up libtext-unidecode-perl (1.30-1) ...
# Setting up fonts-tlwg-kinnari-otf (1:0.7.3-1) ...
# Setting up libfile-homedir-perl (1.006-1) ...
# Setting up texlive-lang-european (2021.20220204-1) ...
# Setting up texlive-metapost-doc (2021.20220204-1) ...
# Setting up latex-cjk-japanese-wadalab (0.20050817-17.1) ...
# Setting up libsys-hostname-long-perl (1.5-2) ...
# Setting up libemf1:amd64 (1.0.13-3) ...
# Setting up psutils (1.17.dfsg-4) ...
# Setting up libevdev2:amd64 (1.12.1+dfsg-1) ...
# Setting up libtext-roman-perl (3.5-2.1) ...
# Setting up openjade (1.4devel1-22) ...
# Setting up liburi-perl (5.10-1) ...
# Setting up info (6.8-4build1) ...
# update-alternatives: using /usr/bin/info to provide /usr/bin/infobrowser (infobrowser) in auto mode
# Setting up asymptote-doc (2.78+ds-2) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up xbitmaps (1.1.1-2.1ubuntu1) ...
# Setting up latex-cjk-korean (4.8.4+git20170127-4) ...
# Setting up lcdf-typetools (2.108-2) ...
# Setting up chktex (1.7.6-4) ...
# Setting up libxm4:amd64 (2.3.8-3) ...
# Setting up texlive-publishers-doc (2021.20220204-1) ...
# Setting up fonts-tlwg-typewriter (1:0.7.3-1) ...
# Setting up texlive-music (2021.20220204-1) ...
# Setting up libhttp-message-perl (6.36-1) ...
# Setting up libtext-csv-perl (2.01-1) ...
# Setting up libwacom-common (2.2.0-1) ...
# Setting up cm-super-minimal (0.3.4-17) ...
# Setting up libnet-ssleay-perl:amd64 (1.92-1build2) ...
# Setting up libjson-xs-perl (4.030-1build3) ...
# Setting up libhttp-negotiate-perl (6.01-1) ...
# Setting up fonts-tlwg-typo (1:0.7.3-1) ...
# Setting up libjxr-tools (1.2~git20170615.f752187-5) ...
# Setting up fonts-tlwg-waree (1:0.7.3-1) ...
# Setting up texlive-lang-korean (2021.20220204-1) ...
# Setting up libtext-bibtex-perl (0.88-3build3) ...
# Setting up libhttp-cookies-perl (6.10-1) ...
# Setting up cups-bsd (2.4.1op1-1ubuntu4.7) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Setting up libwacom9:amd64 (2.2.0-1) ...
# Setting up texlive-lang-czechslovak (2021.20220204-1) ...
# Setting up liblist-moreutils-perl (0.430-2) ...
# Setting up dvipng (1.15-1.1) ...
# Setting up libdjvulibre21:amd64 (3.5.28-2build2) ...
# Setting up fonts-tlwg-sawasdee (1:0.7.3-1) ...
# Setting up libnet-http-perl (6.22-1) ...
# Setting up libtext-csv-xs-perl:amd64 (1.47-1build1) ...
# Setting up libipc-shareable-perl (1.06-2) ...
# Setting up gsfonts-x11 (0.28) ...
# Setting up libexception-class-perl (1.45-1) ...
# Setting up fonts-tlwg-typist (1:0.7.3-1) ...
# Setting up libclass-c3-perl (0.35-1) ...
# Setting up libdevel-callchecker-perl (0.008-1ubuntu4) ...
# Setting up libxml-sax-perl (1.02+dfsg-3) ...
# update-perl-sax-parsers: Registering Perl SAX parser XML::SAX::PurePerl with priority 10...
# update-perl-sax-parsers: Updating overall Perl SAX parser modules info file...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
#
# Creating config file /etc/perl/XML/SAX/ParserDetails.ini with new version
# Setting up texlive-lang-other (2021.20220204-1) ...
# Setting up libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libdata-compare-perl (1.27-1) ...
# Setting up libinput-bin (1.20.0-1ubuntu0.3) ...
# Setting up texlive-lang-chinese (2021.20220204-1) ...
# Setting up libmail-sendmail-perl (0.80-1.1) ...
# Setting up libmagickcore-6.q16-6:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Setting up texlive-formats-extra (2021.20220204-1) ...
# Setting up libqt5xml5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up fonts-tlwg-kinnari (1:0.7.3-1) ...
# Setting up libunicode-linebreak-perl (0.0.20190101-1build3) ...
# Setting up libdata-optlist-perl (0.112-1) ...
# Setting up latex-cjk-japanese (4.8.4+git20170127-4) ...
# Setting up latex-cjk-chinese (4.8.4+git20170127-4) ...
# Setting up libxml-libxml-perl (2.0207+dfsg+really+2.0134-1) ...
# update-perl-sax-parsers: Registering Perl SAX parser XML::LibXML::SAX::Parser with priority 50...
# update-perl-sax-parsers: Registering Perl SAX parser XML::LibXML::SAX with priority 50...
# update-perl-sax-parsers: Updating overall Perl SAX parser modules info file...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Replacing config file /etc/perl/XML/SAX/ParserDetails.ini with new version
# Setting up libwacom-bin (2.2.0-1) ...
# Setting up libwww-robotrules-perl (6.02-1) ...
# Setting up libhttp-daemon-perl (6.13-1ubuntu0.1) ...
# Setting up libhtml-parser-perl:amd64 (3.76-1build2) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up libmagickwand-6.q16-6:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Setting up cm-super (0.3.4-17) ...
# Creating fonts. This may take some time... done.
# Setting up xterm (372-1ubuntu1) ...
# update-alternatives: using /usr/bin/xterm to provide /usr/bin/x-terminal-emulator (x-terminal-emulator) in auto mode
# update-alternatives: using /usr/bin/lxterm to provide /usr/bin/x-terminal-emulator (x-terminal-emulator) in auto mode
# Setting up libmro-compat-perl (0.15-1) ...
# Setting up xpdf (3.04+git20220201-1) ...
# Setting up libmagick++-6.q16-8:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Setting up libio-socket-ssl-perl (2.074-2) ...
# Setting up libsub-exporter-perl (0.988-1) ...
# Setting up libeval-closure-perl (0.14-1) ...
# Setting up libhtml-form-perl (6.07-1) ...
# Setting up libinput10:amd64 (1.20.0-1ubuntu0.3) ...
# Setting up libparams-validationcompiler-perl (0.30-1) ...
# Setting up libpstoedit0c2a:amd64 (3.78-1) ...
# Setting up libmagickcore-6.q16-6-extra:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Setting up libhtml-tree-perl (5.07-2) ...
# Setting up libparams-classify-perl (0.015-1build5) ...
# Setting up libxml-libxml-simple-perl (1.01-1) ...
# Setting up latex-cjk-thai (4.8.4+git20170127-4) ...
# Setting up libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libhtml-format-perl (2.12-1.1) ...
# Setting up qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up latex-cjk-all (4.8.4+git20170127-4) ...
# Setting up libnet-smtp-ssl-perl (1.04-1) ...
# Setting up libmodule-runtime-perl (0.016-1) ...
# Setting up libmailtools-perl (2.21-1) ...
# Setting up texlive-extra-utils (2021.20220204-1) ...
# Setting up libdist-checkconflicts-perl (0.11-1.1) ...
# Setting up texinfo (6.8-4build1) ...
# Running mktexlsr. This may take some time. ... done.
# Setting up libxml-libxslt-perl (1.99-1build2) ...
# Setting up imagemagick-6.q16 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# update-alternatives: using /usr/bin/compare-im6.q16 to provide /usr/bin/compare (compare) in auto mode
# update-alternatives: using /usr/bin/compare-im6.q16 to provide /usr/bin/compare-im6 (compare-im6) in auto mode
# update-alternatives: using /usr/bin/animate-im6.q16 to provide /usr/bin/animate (animate) in auto mode
# update-alternatives: using /usr/bin/animate-im6.q16 to provide /usr/bin/animate-im6 (animate-im6) in auto mode
# update-alternatives: using /usr/bin/convert-im6.q16 to provide /usr/bin/convert (convert) in auto mode
# update-alternatives: using /usr/bin/convert-im6.q16 to provide /usr/bin/convert-im6 (convert-im6) in auto mode
# update-alternatives: using /usr/bin/composite-im6.q16 to provide /usr/bin/composite (composite) in auto mode
# update-alternatives: using /usr/bin/composite-im6.q16 to provide /usr/bin/composite-im6 (composite-im6) in auto mode
# update-alternatives: using /usr/bin/conjure-im6.q16 to provide /usr/bin/conjure (conjure) in auto mode
# update-alternatives: using /usr/bin/conjure-im6.q16 to provide /usr/bin/conjure-im6 (conjure-im6) in auto mode
# update-alternatives: using /usr/bin/import-im6.q16 to provide /usr/bin/import (import) in auto mode
# update-alternatives: using /usr/bin/import-im6.q16 to provide /usr/bin/import-im6 (import-im6) in auto mode
# update-alternatives: using /usr/bin/identify-im6.q16 to provide /usr/bin/identify (identify) in auto mode
# update-alternatives: using /usr/bin/identify-im6.q16 to provide /usr/bin/identify-im6 (identify-im6) in auto mode
# update-alternatives: using /usr/bin/stream-im6.q16 to provide /usr/bin/stream (stream) in auto mode
# update-alternatives: using /usr/bin/stream-im6.q16 to provide /usr/bin/stream-im6 (stream-im6) in auto mode
# update-alternatives: using /usr/bin/display-im6.q16 to provide /usr/bin/display (display) in auto mode
# update-alternatives: using /usr/bin/display-im6.q16 to provide /usr/bin/display-im6 (display-im6) in auto mode
# update-alternatives: using /usr/bin/montage-im6.q16 to provide /usr/bin/montage (montage) in auto mode
# update-alternatives: using /usr/bin/montage-im6.q16 to provide /usr/bin/montage-im6 (montage-im6) in auto mode
# update-alternatives: using /usr/bin/mogrify-im6.q16 to provide /usr/bin/mogrify (mogrify) in auto mode
# update-alternatives: using /usr/bin/mogrify-im6.q16 to provide /usr/bin/mogrify-im6 (mogrify-im6) in auto mode
# Setting up feynmf (1.08-13) ...
# Setting up libpoppler-qt5-1:amd64 (22.02.0-2ubuntu0.2) ...
# Setting up fragmaster (1.7-10) ...
# Setting up pstoedit (3.78-1) ...
# Setting up libmime-lite-perl (3.033-1) ...
# Setting up libmodule-implementation-perl (0.09-1.1) ...
# Setting up libpackage-stash-perl (0.39-1) ...
# Setting up libqt5svg5:amd64 (5.15.3-1) ...
# Setting up liblist-someutils-perl (0.58-1) ...
# Setting up vprerex (1:6.5.1-1build1) ...
# Setting up asymptote (2.78+ds-2) ...
# Setting up libspecio-perl (0.47-1) ...
# Setting up liblist-someutils-xs-perl (0.58-2build3) ...
# Setting up liblist-allutils-perl (0.19-1) ...
# Setting up imagemagick (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3) ...
# Setting up libparams-validate-perl:amd64 (1.30-1build3) ...
# Setting up libb-hooks-endofscope-perl (0.25-1) ...
# Setting up purifyeps (1.1-3) ...
# Setting up libnamespace-clean-perl (0.27-1) ...
# Setting up libnamespace-autoclean-perl (0.29-1) ...
# Setting up libdatetime-locale-perl (1:1.33-1) ...
# Setting up libdatetime-timezone-perl (1:2.51-1+2021e) ...
# Setting up liblog-dispatch-perl (2.70-1) ...
# Setting up libdatetime-perl:amd64 (2:1.55-1build1) ...
# Setting up libdatetime-format-strptime-perl (1.7900-1) ...
# Setting up libdatetime-calendar-julian-perl (0.107-1) ...
# Setting up libdatetime-format-builder-perl (0.8300-1) ...
# Setting up libwww-perl (6.61-1) ...
# Setting up libbusiness-isbn-perl (3.006-1) ...
# Setting up liblwp-protocol-https-perl (6.10-1) ...
# Setting up libxml-parser-perl:amd64 (2.46-3build1) ...
# Setting up libxml-sax-expat-perl (0.51-1) ...
# update-perl-sax-parsers: Registering Perl SAX parser XML::SAX::Expat with priority 50...
# update-perl-sax-parsers: Updating overall Perl SAX parser modules info file...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Replacing config file /etc/perl/XML/SAX/ParserDetails.ini with new version
# Setting up biber (2.17-2) ...
# Setting up texlive-full (2021.20220204-1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for tex-common (6.17) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Running mktexlsr. This may take some time... done.
# Running mtxrun --generate. This may take some time... done.
# Running updmap-sys. This may take some time... done.
# Running mktexlsr /var/lib/texmf ... done.
# Building format(s) --all.
# 	This may take some time... done.
# Processing triggers for install-info (6.8-4build1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for sgml-base (1.30) ...

# %%
# %%manim -qm -v WARNING SquareToCircle
#
# class SquareToCircle(Scene):
#    def construct(self):
#       square = Square()
#       circle = Circle()
#       circle.set_fill(PINK, opacity=0.5)
#       self.play(Create(square))
#       self.play(Transform(square, circle))
#       self.wait()
# Out:
# UsageError: Cell magic `%%manim` not found.
